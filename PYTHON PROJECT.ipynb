# %%
#@title

# %%
pip install colorama

# %%
#@title
import random
from IPython.display import Image
from IPython.display import YouTubeVideo
from colorama import Fore
import time

class quiz:

  def __init__(self,q,opt,ans,path):   
    self.q=q
    self.opt=opt
    self.ans=ans
    self.path=path

e1=[quiz("Who invented the Marauders Map? ",["Moony, Padfoot, Dobby, Fluffy","Prongs, Tonks, Winky, Peeves","Padfoot, Peter, Filch, Quirrell"],"Moony, Wormtail, Padfoot, Prongs",'marauders map.jpg'),
   quiz("How many Horcruxes did Voldemort create? ",["6","8","9"],"7",'Horcruxes.jpg'),
   quiz("Who is Harry's Godfather? ",["Remus Lupin ","Peter Pettigrew","James Potter"],"Sirius Black",'Sirius2.jpg'),
   quiz("In which book was Dumbledore killed?",["The Prisoner of Azkaban","The Chamber of Secrets","The Order of Pheonix"],"The Half-Blood Prince",'Dumbledore death.jpg'),
   quiz("What form does Rita Skeeter take as an Animagus?",["A Bird","A Snake","A Squirrel"],"A Beetle",'Rita skeeter.jpg')]

m1=[quiz("What is Voldemort's real name? ",["Tom Marvon Riddle","Tom Marvil Riddle","Tom Ravolo Riddle"],"Tom Marvolo Riddle",'Voldemort.jpg'),
   quiz("What does S.P.E.W stand for?",["Society for the Protection of Elves and Wizards","Society for protection of People,Elves and Wizards","Sorority for the Protection of Elves and Wands"],"Society for the Promotion of Elfish Welfare",'SPEW.jpg'),
   quiz("What is Dumbledore's full name?",["Albus Wulfric Percival Brian Dumbledore","Albus Percival Brian Wulfric Dumbledore","Albus Brian Percival Wulfric Dumbledore"],"Albus Percival Wulfric Brian Dumbledore",'Dumbledore.jpg'),
   quiz("Which brothers are supposedly the original possessors of the Deathly Hallows?",["The Percival Brothers","The Perival Brothers","The Possimo Brothers"],"The Peverell brothers",'Peverell Bros.jpg'),
   quiz("Who is the Hufflepuff house ghost?",["Cuthbert Binns","Sir Patrick Delaney-Podmore","The Grey Lady"],"The Fat Friar",'Hufflepuff_ghost.jpg')]

h1=[quiz("Slughorn teaches his students that Amortentia smells different to each person. What food does Harry smell?",["Pumpkin Juice","Mrs. Weasley's fudge","Chocolate frogs"],"Treacle Tart",'Treacle Tart.jpg'),
   quiz("Who was the headmaster of Hogwarts when the Chamber of Secrets was opened for the first time?",["Albus Dumbledore","Phineas Nigellus Black","Brutus Scrimgeour"],"Armando Dippet",'Armando dippet.jpg'),
   quiz("How many sickles are in a galleon?",["15","14","19"],"17",'GAlleon.jpg'),
   quiz("Which creatures pull the carriages that take students from the Hogwarts Express to the Castle?",["Hippogriffs","Manticores","Centaurs"],"Thestrals",'thestrals.jpg'),
   quiz("Which map did Dumbledore have on his knee?",["The Marauders Map","The Hogwarts Map","The Hogsmeade Map"],"The London Underground Map",'dumbledore scar.jpg')]

e2=[quiz('Which was the infinity stone which was with Dr Strange ?',['Soul stone','Power stone','Space stone'],'Time stone','Q1.jpg'),
    quiz('Which Avenger Made A Cameo In Thor?',['Black Widow','Iron Man','Captain America'],'Hawkeye','Q2.jpg'),
    quiz('Which of these is not a member of the Guardians of the Galaxy?',['Gamora','Star Lord','Groot'],'Ronan','Q3.jpg'),
    quiz('Which of these did not appear in X-MEN origins Wolverine ?',['Cyclops','Emma Forest','Toad'],'Jubilee','wolverine.jpg'),
    quiz('Which spidey villain was not referenced?',['Vulture','Dr Octopus','Rhino'],'Scorpion','Q5.jpg')]


m2=[quiz('When did we first hear of Dr Strange?',['Iron Man-03','Thor-the dark world','Avengers:Age of Ultron'],'Captain America and the Winter soldier','DR STRANGE.jpg'),
    quiz('Which Marvel role was it, though, that Johansson so nearly landed before her involvement as Black Widow?',['Betty Ross','Felica Hardy','Pepper Potts'],'Gwen Stacy','q7.jpg'),
    quiz('What year was the first Iron Man movie released, kicking off the Marvel Cinematic Universe?',['2005','2012','2017'],'2008','tony stark.jpg'),
    quiz('Who is Bucky Barnes better known as?',['The red skull','Baron Zemo','None of the above'],'The Winter Soldier','q9.jpg'),
    quiz('Who is Black Panther’s sister?',['Nakia','Ramonda','Okeye'],'Shuri','shuri.jpg')]


h2=[quiz("What are Quicksilver's last words in Avengers: Age of Ultron?",['I Love you','See you soon','Let the game begin'],'You did not see that coming','quicksilver.jpg'),
    quiz('Which of these (translated) words is NOT a trigger for The Winter Soldier?',['Homecoming','Freight car','Seventeen'],'Scissor','winter.jpg'),
    quiz('Which of these characters DID NOT wear an Iron Man suit in Iron Man 3?',['Rhodey','Pepper','President Ellis'],'Happy','happy.jpg'),
    quiz('What is the real name of Red Skull?',['Jorah Newcastle','Joseph Schmidtt','Johanner Wagner'],'Johann Schmidt','Red skull.jpg'),
    quiz('Which song does Baby Groot dance to at the end of The Guardians of the Galaxy?',['Wanna be startin something','O-O-H Child','Uptight'],'I want you back','groot.jpg')]

e3=[quiz("What’s the name of Hopper’s daughter?",["Jane", "Eleven", "Nancy"],"Sara","sara.jpg"),
   quiz("Who is Eleven’s 'sister'?",["Funshine", "Dottie", "Axel"],"Kali","kali.jpg"),
   quiz("Who is Lucas’s 'annoying' little sister?",["EliNza","Ermi","Wait, he has a sister?"],"Erica","erica.jpg"),
   quiz("What was the new girl's name?",["Betty","Mia","Jessica"],"Maxine","max.jpg"),
   quiz("What type of candy/nougat does Dustin feed Dart?",["Snickers","Milky Way","Mars"],"3 Musketeers","feeed.jpg")]

m3=[quiz("What is the project that Eleven was experimented on in Hawkins's lab?",["Project CIA","Project 011","Project NSA"],"Project MKULtra","project.jpg"),
   quiz("Who was the librarian who wasn't too friendly with Hopper?",["Marie","Marisol","Marlene"],"Marissa","marissa.jpg"),
   quiz("To 'get the weirdo in there without noticing' Mike and his friends came up with what name to save Eleven when they were confronted by Mr. Clarke?",["Elise", " Ellie", "Elena"],"Eleanor","eleanor.jpg"),
   quiz("Who is not one of the producers of Stranger Things?",["Matt Duffer","Ross Duffer","Shawn Levy"],"Jimmy Frame","producers.jpg"),
   quiz("What is Eleven and Max's real names?",["Molly Bad Brenner and Stella Sticky","Mia Brown Bra and Stacie Saw","Milly Bob Brinn and Sally Sade"],"Millie Booby Brown and Sadie Sink","name.jpg")]

h3=[quiz("Which was the burger shop where we first see Eleven?",["Billy, owner of Billy’s Burgers","Bob, owner of Bob’s Burgers","Ted, owner of Ted’s Tacos"],"Benny, owner of Benny’s Burgers","burger.jpg"),
   quiz("Which is Dusty bun and suzie poo’s song?",["Till the dawn","May we have a forever","Let’s be together"],"Never ending story","song.jpg"),
   quiz("How long was Eleven in the woods without Hopper?",["2 weeks","353 days","2 months"],"1 month","days.jpg"),
   quiz("What does Alexei say (in Russian) when he tastes the strawberry slurpie?",["What is this? Strawberry!","This is bad!","Why isn’t this cherry!"],"This tastes like sh*t strawberry!","shake.jpg"),
   quiz("Who swears the most in Stranger Things?",["Lucas","Max","Mike"],"Dustin","swear.jpg")]

# %%
#@title
def qt(arg):
  switcher = {
      1:"PLATFORM 9 3/4",
      2:"I LOVE YOU 3000",
      3:"THE UPSIDE DOWN"
  }
  return switcher.get(arg,"nothing")
   
print(Fore.GREEN+"1.PLATFORM 9 3/4")
print(Fore.RED+"2.I LOVE YOU 3000")
print(Fore.CYAN+"3.THE UPSIDE DOWN")
print(Fore.BLACK+"")
name=input("Enter your name : ")

k=int(input("Choose your kind : "))

while k not in [1,2,3]:
  print(Fore.RED+"CHOOSE ONLY FROM 1, 2 OR 3!!!")
  print(Fore.BLACK+"")
  k=int(input("Rechoose your kind : "))
  
score=0
neg=0

if k==1:
  print("\n","Hey there,",name,"!","\n","\n")
  print("Welcome to The Triwizard Cup!! ",'\n')
  print("As you've chosen",qt(k),"! Here you go!!")
  
  print("\n","\n","Do you think you know Hogwarts well enough? Okay, Let's see!! ")
  print(" Also, ever heard of JEE MAINS? Well, the marking scheme for this quiz is same as that!! But here, it's cookies instead marks! So no worries B) ","\n")
  print(" Okay so, first let's start with the EASY Questions Part! ","\n")

  random.shuffle(e1)
  random.shuffle(m1)
  random.shuffle(h1)
  all=[e1,m1,h1]
  all=[y for x in all for y in x]
  Q=0
  for que in all:
    
    print(que.q)
    options=que.opt + [que.ans]
    random.shuffle(options)
    c=0
    while c<len(options):
      print(str(c+1)+'. '+options[c])
      c+=1
    print("Enter the appropriate number of your option : ")
    choice=input()
    while not choice.isdigit():
      print("The entered choice wasn't a number please re-enter your choice : ")
      choice=input()
    choice=int(choice)
    while not(int(choice)>0 and int(choice)<=len(options)):
      print("The number doesn't correspond to any answer. Please enter the number of your answer : ")
      choice=input()
    if options[int(choice)-1]==que.ans:
      print("   Yay! You're right :) ","\n")
      score+=1
      time.sleep(2)
    else:
      print("   Oops! You're wrong :( ")
      print("The right answer is : " + que.ans,"\n")
      neg+=1
      time.sleep(2)
    display(Image(que.path))
    time.sleep(2)
    Q+=1
    if Q == 5:
      print("\n"," As you have finished the Easy-Peasy part, let's see how the MEDIUM Part goes!!","\n")
      time.sleep(3)
    elif Q == 10:
      print("\n"," Now, the Actual Part, that is THE DIFFICULT PART, begins!! ","\n")
      time.sleep(2)

  print("\n","So, the number of cookies you get are", (4*score)-neg,"!!","\n","Have a nice dayyyyyyy ;) ")
  print("")
  
  display(YouTubeVideo('T2fQGZ7_ym0',width= 768,height=432))

elif k==2:
  print("\n","Hey there,",name,"!","\n","\n")
  print("Welcome to The Triwizard Cup!! ",'\n')
  print("As you've chosen",qt(k),"! Here you go!!")
  
  print("\n","\n","Do you think you know Marvel well enough? Okay, Let's see!! ")
  print(" Also, ever heard of JEE MAINS? Well, the marking scheme for this quiz is same as that!! But here, it's cookies instead marks! So no worries B) ","\n")
  print(" Okay so, first let's start with the EASY Questions Part! ","\n")

  random.shuffle(e2)
  random.shuffle(m2)
  random.shuffle(h2)
  all=[e2,m2,h2]
  all=[y for x in all for y in x]
  Q=0
  for que in all:
    
    print(que.q)
    options=que.opt + [que.ans]
    random.shuffle(options)
    c=0
    while c<len(options):
      print(str(c+1)+'. '+options[c])
      c+=1
    print("Enter the appropriate number of your option : ")
    choice=input()
    while not choice.isdigit():
      print("The entered choice wasn't a number please re-enter your choice : ")
      choice=input()
    choice=int(choice)
    while not(int(choice)>0 and int(choice)<=len(options)):
      print("The number doesn't correspond to any answer. Please enter the number of your answer : ")
      choice=input()
    if options[int(choice)-1]==que.ans:
      print("   Yay! You're right :) ","\n")
      score+=1
      time.sleep(2)
    else:
      print("   Oops! You're wrong :( ")
      print("The right answer is : " + que.ans,"\n")
      neg+=1
      time.sleep(2)
    display(Image(que.path))
    time.sleep(2)
    Q+=1
    if Q == 5:
      print("\n"," As you have finished the Easy-Peasy part, let's see how the MEDIUM Part goes!!","\n")
      time.sleep(3)
    elif Q == 10:
      print("\n"," Now, the Actual Part, that is THE DIFFICULT PART, begins!! ","\n")
      time.sleep(2)

  print("\n","So, the number of cookies you get are", (4*score)-neg,"!!","\n","Have a nice dayyyyyyy ;) ")
  print("")
  display(YouTubeVideo('pkTThp4kfhY',width= 768,height=432))
  
elif k==3:
  print("\n","Hey there,",name,"!","\n","\n")
  print("Welcome to The Triwizard Cup!! ",'\n')
  print("As you've chosen",qt(k),"! Here you go!!")
  
  print("\n","\n","Do you think you know Stranger Things well enough? Okay, Let's see!! ")
  print(" Also, ever heard of JEE MAINS? Well, the marking scheme for this quiz is same as that!! But here, it's cookies instead marks! So no worries B) ","\n")
  print(" Okay so, first let's start with the EASY Questions Part! ","\n")

  random.shuffle(e3)
  random.shuffle(m3)
  random.shuffle(h3)
  all=[e3,m3,h3]
  all=[y for x in all for y in x]
  Q=0
  for que in all:
    
    print(que.q)
    options=que.opt + [que.ans]
    random.shuffle(options)
    c=0
    while c<len(options):
      print(str(c+1)+'. '+options[c])
      c+=1
    print("Enter the appropriate number of your option : ")
    choice=input()
    while not choice.isdigit():
      print("The entered choice wasn't a number please re-enter your choice : ")
      choice=input()
    choice=int(choice)
    while not(int(choice)>0 and int(choice)<=len(options)):
      print("The number doesn't correspond to any answer. Please enter the number of your answer : ")
      choice=input()
    if options[int(choice)-1]==que.ans:
      print("   Yay! You're right :) ","\n")
      score+=1
      time.sleep(2)
    else:
      print("   Oops! You're wrong :( ")
      print("The right answer is : " + que.ans,"\n")
      neg+=1
      time.sleep(2)
    display(Image(que.path))
    time.sleep(2)
    Q+=1
    if Q == 5:
      print("\n"," As you have finished the Easy-Peasy part, let's see how the MEDIUM Part goes!!","\n")
      time.sleep(3)
    elif Q == 10:
      print("\n"," Now, the Actual Part, that is THE DIFFICULT PART, begins!! ","\n")
      time.sleep(2)

  print("\n","So, the number of cookies you get are", (4*score)-neg,"!!","\n","Have a nice dayyyyyyy ;) ")
  print("")
  
  display(YouTubeVideo('phT1OKgSflI',width= 768,height=432))
